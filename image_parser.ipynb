# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexeyMasalykin/Image_Parser/blob/main/image_parser.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import requests
import pandas as pd
from googleapiclient.discovery import build
from IPython.display import display, Image

# %% [markdown]
# Основной код парсера

# %%
API_KEY = "AIzaSyCBoel_EghzX-z0GHiF2NFcczuDo0lY1C0"
CX = "f7496f16acdd14671"

query = "рентген легких c патологиями"
num_images = 20

service = build("customsearch", "v1", developerKey=API_KEY)

def google_image_search(query, num_results):
    image_urls = []
    start_index = 1
    while len(image_urls) < num_results:
        num = min(10, num_results - len(image_urls))
        res = service.cse().list(
            q=query,
            cx=CX,
            searchType='image',
            num=num,
            start=start_index
        ).execute()

        for item in res.get('items', []):
            image_urls.append({
                'title': item.get('title'),
                'link': item.get('link'),
                'mime': item.get('mime'),
                'width': item.get('image', {}).get('width'),
                'height': item.get('image', {}).get('height')
            })
        start_index += num
    return image_urls

print("Ищем изображения...")
images = google_image_search(query, num_images)

df = pd.DataFrame(images)
display(df)

df.to_csv("images_info.csv", index=False, encoding='utf-8')
print("Информация об изображениях сохранена в images_info.csv")

images_dir = "z"
os.makedirs(images_dir, exist_ok=True)

def download_image(url, path):
    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status()
        with open(path, 'wb') as f:
            f.write(response.content)
        print(f"Скачано: {path}")
    except Exception as e:
        print(f"Ошибка при скачивании {url}: {e}")

print("Скачиваем изображения...")
for idx, row in df.iterrows():
    image_url = row['link']


    file_extension = os.path.splitext(image_url)[1]
    if not file_extension.lower() in [".jpg", ".jpeg", ".png", ".gif", ".bmp"]:
        file_extension = ".jpg"
    file_name = f"image_{idx+1}{file_extension}"
    file_path = os.path.join(images_dir, file_name)
    download_image(image_url, file_path)

print("Скачивание завершено.")
# Out:
# Ищем изображения...
#                                                 title  \
# 0   Amazon.com: Инфекционные заболевания легких: и...
# 1   Роман Викторович Шутов | Пришли результаты 3 П...
# 2   Amazon.com: Туберкулез легких и тромболитическ...
# 3   Не откладывайте заботу о легких! 🌬️ Задумывали...
# 4   Неделя профилактики рака лёгких - Администраци...
# 5   Гематолог | Москва | Недавно консультировал па...
# 6                              Стоматология в Чхонане
# 7   ПРАВИЛЬНОЕ ПИТАНИЕ EAT&FIT | АСТАНА | АЛМАТЫ |...
# 8   Коронавирусная инфекция COVID-19: профилактика...
# 9   Педиатр👩🏻‍⚕️Деревкова Анастасия Александровна ...
# 10  Прикроватное ультразвуковое исследование легки...
# 11  Лучевая диагностика заболевания грудной клетки...
# 12                                   Постерная сессия
# 13  Медицинский центр "ШИПАГЕР-С" АКТОБЕ | 🩻 **Ког...
# 14  КТ органов грудной клетки - Отделение КТ и МРТ...
# 15  ФГБУ "НМИЦ фтизиопульмонологии и инфекционных ...
# 16  Легкое дыхание»: как не допустить рака легких ...
# 17  Рекомендации по проведению вакцинации против и...
# 18  Классификация и обнаружение ковид-19 в ультраз...
# 19  О коронавирусе | Республиканский реабилитацион...
#
#                                                  link        mime  width  \
# 0   https://m.media-amazon.com/images/I/51IJi-Ovzi...  image/jpeg    681
# 1   https://lookaside.instagram.com/seo/google_wid...      image/   1439
# 2   https://m.media-amazon.com/images/I/61nqD4ybyO...  image/jpeg    681
# 3   https://lookaside.instagram.com/seo/google_wid...      image/   1080
# 4   https://maksatiha-adm.ru/wp-content/uploads/20...  image/jpeg    720
# 5   https://lookaside.instagram.com/seo/google_wid...      image/   1440
# 6   https://lookaside.fbsbx.com/lookaside/crawler/...      image/    720
# 7   https://lookaside.instagram.com/seo/google_wid...      image/   1280
# 8   https://i.ytimg.com/vi/Eg3b1emmyew/maxresdefau...  image/jpeg   1280
# 9   https://lookaside.instagram.com/seo/google_wid...      image/   1440
# 10  https://m.media-amazon.com/images/I/61Sn6DmqZ2...  image/jpeg    238
# 11  https://lookaside.fbsbx.com/lookaside/crawler/...      image/   1152
# 12  https://cfpd.ru/upload/medialibrary/240/2o6dby...  image/jpeg   1024
# 13  https://lookaside.instagram.com/seo/google_wid...      image/   1080
# 14  https://sklif-kt.ru/assets/components/phpthumb...   image/png    900
# 15  https://lookaside.fbsbx.com/lookaside/crawler/...      image/   1412
# 16  https://st-vestnik.ru/wp-content/uploads/2024/...  image/jpeg    336
# 17  https://gor-roddom2.by/images/news/2021/listov...  image/jpeg   1654
# 18  https://m.media-amazon.com/images/I/51AtXyaLZR...  image/jpeg    238
# 19  http://www.reacenter.by/images/2020/04/02/2cov...  image/jpeg   2250
#
#     height
# 0     1000
# 1     1799
# 2     1000
# 3     1080
# 4     1280
# 5     1440
# 6      960
# 7     1280
# 8      720
# 9     1440
# 10     350
# 11    1320
# 12     764
# 13    1920
# 14     677
# 15    1957
# 16     500
# 17    2339
# 18     350
# 19    3250
# Информация об изображениях сохранена в images_info.csv
# Скачиваем изображения...
# Скачано: z/image_1.jpg
# Скачано: z/image_2.jpg
# Скачано: z/image_3.jpg
# Скачано: z/image_4.jpg
# Скачано: z/image_5.jpeg
# Скачано: z/image_6.jpg
# Скачано: z/image_7.jpg
# Скачано: z/image_8.jpg
# Скачано: z/image_9.jpg
# Скачано: z/image_10.jpg
# Скачано: z/image_11.jpg
# Скачано: z/image_12.jpg
# Скачано: z/image_13.jpg
# Скачано: z/image_14.jpg
# Скачано: z/image_15.png
# Скачано: z/image_16.jpg
# Скачано: z/image_17.jpg
# Скачано: z/image_18.jpg
# Скачано: z/image_19.jpg
# Скачано: z/image_20.jpg
# Скачивание завершено.
